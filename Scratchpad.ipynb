# %%
import requests
import json
import time
from string import ascii_uppercase
from pathlib import Path
import pandas as pd

BATCH_SIZE = 1000
MAX_PAGES_PER_COMBO = 10
SLEEP_TIME = 0.5

# Output base folder
base_dir = Path("raw/hsc_achievers_yearly")
base_dir.mkdir(parents=True, exist_ok=True)

# Process each year from 2018 to 2024
for year in range(2018, 2019):
    print(f"\n📅 Starting year: {year}")
    index_name = f"prod_nesa_{year}_hsc_distinguished_achievers_rectified"
    BASE_URL = f"https://www.nsw.gov.au/api/v1/elasticsearch/{index_name}/_search"

    year_dir = base_dir / str(year)
    year_dir.mkdir(parents=True, exist_ok=True)

    seen_ids = set()

    # Track all source entries to export as CSV later
    full_year_data = []

    for first_initial in ascii_uppercase:
        for last_initial in ascii_uppercase:
            pair_id = f"{first_initial}_{last_initial}"
            pair_path = year_dir / f"{pair_id}.jsonl"

            if pair_path.exists():
                print(f"✅ Skipping {pair_id} for {year} (already saved)")
                continue

            print(f"🔍 {year} - {pair_id}")

            for page in range(MAX_PAGES_PER_COMBO):
                offset = page * BATCH_SIZE

                query = {
                    "from": offset,
                    "size": BATCH_SIZE,
                    "query": {
                        "bool": {
                            "must": [
                                {
                                    "query_string": {
                                        "query": f"{first_initial}*",
                                        "fields": ["first_name"],
                                        "rewrite": "scoring_boolean"
                                    }
                                },
                                {
                                    "query_string": {
                                        "query": f"{last_initial}*",
                                        "fields": ["last_name"],
                                        "rewrite": "scoring_boolean"
                                    }
                                }
                            ]
                        }
                    },
                    "sort": [{"_score": {"order": "desc"}}]
                }

                params = {
                    "source_content_type": "application/json",
                    "source": json.dumps(query)
                }

                try:
                    response = requests.get(BASE_URL, params=params)
                    response.raise_for_status()
                    data = response.json()
                    hits = data.get("hits", {}).get("hits", [])

                    if not hits:
                        break

                    new_hits = []
                    for hit in hits:
                        if hit["_id"] not in seen_ids:
                            seen_ids.add(hit["_id"])
                            new_hits.append(hit)
                            full_year_data.append(hit["_source"])

                    if new_hits:
                        with pair_path.open("a") as f:
                            for hit in new_hits:
                                f.write(json.dumps(hit) + "\n")

                        print(f"📦 Page {page+1}: {len(new_hits)} new records")
                    else:
                        print(f"🛑 Page {page+1}: No new records")
                        break

                    time.sleep(SLEEP_TIME)

                except Exception as e:
                    print(f"❌ Error: {e}")
                    break

    # Save all results for the year as CSV
    if full_year_data:
        df = pd.DataFrame(full_year_data)
        csv_path = year_dir.parent / f"{year}_distinguished_achievers.csv"
        df.to_csv(csv_path, index=False)
        print(f"💾 Saved full CSV for {year} with {len(df)} records")

print("\n✅ All years completed.")
# Out:
# 📅 Starting year: 2018
# 🔍 2018 - A_A
# 📦 Page 1: 292 new records
# 🔍 2018 - A_B
# 📦 Page 1: 323 new records
# 🔍 2018 - A_C
# 📦 Page 1: 374 new records
# 🔍 2018 - A_D
# 📦 Page 1: 184 new records
# 🔍 2018 - A_E
# 📦 Page 1: 59 new records
# 🔍 2018 - A_F
# 📦 Page 1: 166 new records
# 🔍 2018 - A_G
# 📦 Page 1: 225 new records
# 🔍 2018 - A_H
# 🔍 2018 - Q_G
# 🔍 2018 - Q_H
# 📦 Page 1: 2 new records
# 🔍 2018 - Q_I
# 🔍 2018 - Q_J
# 📦 Page 1: 4 new records
# 🔍 2018 - Q_K
# 🔍 2018 - Q_L
# 📦 Page 1: 4 new records
# 🔍 2018 - Q_M
# 🔍 2018 - Q_N
# 📦 Page 1: 4 new records
# 🔍 2018 - Q_O
# 🛑 Page 1: No new records
# 🔍 2018 - Q_P
# 📦 Page 1: 2 new records
# 🔍 2018 - Q_Q
# 📦 Page 1: 1 new records
# 🔍 2018 - Q_R
# 📦 Page 1: 1 new records
# 🔍 2018 - Q_S
# 📦 Page 1: 2 new records
# 🔍 2018 - Q_T
# 🛑 Page 1: No new records
# 🔍 2018 - Q_U
# 🔍 2018 - Q_V
# 📦 Page 1: 1 new records
# 🔍 2018 - Q_W
# 📦 Page 1: 11 new records
# 🔍 2018 - Q_X
# 🛑 Page 1: No new records
# 🔍 2018 - Q_Y
# 📦 Page 1: 2 new records
# 🔍 2018 - Q_Z
# 📦 Page 1: 9 new records
# 🔍 2018 - R_A
# 📦 Page 1: 75 new records
# 🔍 2018 - R_B
# 📦 Page 1: 122 new records
# 🔍 2018 - R_C
# 📦 Page 1: 95 new records
# 🔍 2018 - R_D
# 📦 Page 1: 85 new records
# 🔍 2018 - R_E
# 📦 Page 1: 22 new records
# 🔍 2018 - R_F
# 📦 Page 1: 20 new records
# 🔍 2018 - R_G
# 📦 Page 1: 45 new records
# 🔍 2018 - R_H
# 📦 Page 1: 56 new records
# 🔍 2018 - R_I
# 📦 Page 1: 4 new records
# 🔍 2018 - R_J
# 📦 Page 1: 15 new records
# 🔍 2018 - R_K
# 📦 Page 1: 57 new records
# 🔍 2018 - R_L
# 📦 Page 1: 93 new records
# 🔍 2018 - R_M
# 📦 Page 1: 107 new records
# 🔍 2018 - R_N
# 📦 Page 1: 36 new records
# 🔍 2018 - R_O
# 📦 Page 1: 24 new records
# 🔍 2018 - R_P
# 📦 Page 1: 37 new records
# 🔍 2018 - R_Q
# 📦 Page 1: 14 new records
# 🔍 2018 - R_R
# 📦 Page 1: 77 new records
# 🔍 2018 - R_S
# 📦 Page 1: 98 new records
# 🔍 2018 - R_T
# 📦 Page 1: 42 new records
# 🔍 2018 - R_U
# 🛑 Page 1: No new records
# 🔍 2018 - R_V
# 📦 Page 1: 21 new records
# 🔍 2018 - R_W
# 📦 Page 1: 53 new records
# 🔍 2018 - R_X
# 📦 Page 1: 17 new records
# 🔍 2018 - R_Y
# 📦 Page 1: 15 new records
# 🔍 2018 - R_Z
# 📦 Page 1: 28 new records
# 🔍 2018 - S_A
# 📦 Page 1: 88 new records
# 🔍 2018 - S_B
# 📦 Page 1: 168 new records
# 🔍 2018 - S_C
# 📦 Page 1: 177 new records
# 🔍 2018 - S_D
# 📦 Page 1: 92 new records
# 🔍 2018 - S_E
# 📦 Page 1: 40 new records
# 🔍 2018 - S_F
# 📦 Page 1: 54 new records
# 🔍 2018 - S_G
# 📦 Page 1: 92 new records
# 🔍 2018 - S_H
# 🛑 Page 1: No new records
# 🔍 2018 - U_J
# 📦 Page 1: 2 new records
# 🔍 2018 - U_K
# 📦 Page 1: 2 new records
# 🔍 2018 - U_L
# 🛑 Page 1: No new records
# 🔍 2018 - U_M
# 📦 Page 1: 4 new records
# 🔍 2018 - U_N
# 🛑 Page 1: No new records
# 🔍 2018 - U_O
# 🛑 Page 1: No new records
# 🔍 2018 - U_P
# 📦 Page 1: 1 new records
# 🔍 2018 - U_Q
# 🔍 2018 - U_R
# 🛑 Page 1: No new records
# 🔍 2018 - U_S
# 📦 Page 1: 5 new records
# 🔍 2018 - U_T
# 🔍 2018 - U_U
# 🔍 2018 - U_V
# 🔍 2018 - U_W
# 🔍 2018 - U_X
# 🔍 2018 - U_Y
# 🔍 2018 - U_Z
# 🔍 2018 - V_A
# 📦 Page 1: 21 new records
# 🔍 2018 - V_B
# 📦 Page 1: 21 new records
# 🔍 2018 - V_C
# 📦 Page 1: 30 new records
# 🔍 2018 - V_D
# 📦 Page 1: 12 new records
# 🔍 2018 - V_E
# 📦 Page 1: 4 new records
# 🔍 2018 - V_F
# 📦 Page 1: 11 new records
# 🔍 2018 - V_G
# 📦 Page 1: 6 new records
# 🔍 2018 - V_H
# 📦 Page 1: 26 new records
# 🔍 2018 - V_I
# 🛑 Page 1: No new records
# 🔍 2018 - V_J
# 📦 Page 1: 23 new records
# 🔍 2018 - V_K
# 📦 Page 1: 20 new records
# 🔍 2018 - V_L
# 📦 Page 1: 35 new records
# 🔍 2018 - V_M
# 📦 Page 1: 28 new records
# 🔍 2018 - V_N
# 📦 Page 1: 16 new records
# 🔍 2018 - V_O
# 🔍 2018 - V_P
# 📦 Page 1: 18 new records
# 🔍 2018 - V_Q
# 🔍 2018 - V_R
# 📦 Page 1: 21 new records
# 🔍 2018 - V_S
# 📦 Page 1: 26 new records
# 🔍 2018 - V_T
# 📦 Page 1: 31 new records
# 🔍 2018 - V_U
# 🔍 2018 - V_V
# 📦 Page 1: 9 new records
# 🔍 2018 - V_W
# 📦 Page 1: 20 new records
# 🔍 2018 - V_X
# 📦 Page 1: 8 new records
# 🔍 2018 - V_Y
# 📦 Page 1: 10 new records
# 🔍 2018 - V_Z
# 📦 Page 1: 16 new records
# 🔍 2018 - W_A
# 📦 Page 1: 5 new records
# 🔍 2018 - W_B
# 📦 Page 1: 25 new records
# 🔍 2018 - W_C
# 📦 Page 1: 20 new records
# 🔍 2018 - W_D
# 📦 Page 1: 20 new records
# 🔍 2018 - W_E
# 📦 Page 1: 1 new records
# 🔍 2018 - W_F
# 📦 Page 1: 6 new records
# 🔍 2018 - W_G
# 📦 Page 1: 17 new records
# 🔍 2018 - W_H
# 📦 Page 1: 34 new records
# 🔍 2018 - W_I
# 🛑 Page 1: No new records
# 🔍 2018 - W_J
# 📦 Page 1: 5 new records
# 🔍 2018 - W_K
# 📦 Page 1: 7 new records
# 🔍 2018 - W_L
# 📦 Page 1: 26 new records
# 🔍 2018 - W_M
# 📦 Page 1: 25 new records
# 🔍 2018 - W_N
# 📦 Page 1: 4 new records
# 🔍 2018 - Y_P
# 📦 Page 1: 18 new records
# 🔍 2018 - Y_Q
# 📦 Page 1: 5 new records
# 🔍 2018 - Y_R
# 📦 Page 1: 6 new records
# 🔍 2018 - Y_S
# 📦 Page 1: 42 new records
# 🔍 2018 - Y_T
# 📦 Page 1: 5 new records
# 🔍 2018 - Y_U
# 📦 Page 1: 1 new records
# 🔍 2018 - Y_V
# 🔍 2018 - Y_W
# 📦 Page 1: 48 new records
# 🔍 2018 - Y_X
# 📦 Page 1: 14 new records
# 🔍 2018 - Y_Y
# 📦 Page 1: 21 new records
# 🔍 2018 - Y_Z
# 📦 Page 1: 62 new records
# 🔍 2018 - Z_A
# 📦 Page 1: 26 new records
# 🔍 2018 - Z_B
# 📦 Page 1: 9 new records
# 🔍 2018 - Z_C
# 📦 Page 1: 27 new records
# 🔍 2018 - Z_D
# 📦 Page 1: 12 new records
# 🔍 2018 - Z_E
# 📦 Page 1: 21 new records
# 🔍 2018 - Z_F
# 📦 Page 1: 23 new records
# 🔍 2018 - Z_G
# 📦 Page 1: 10 new records
# 🔍 2018 - Z_H
# 📦 Page 1: 28 new records
# 🔍 2018 - Z_I
# 📦 Page 1: 8 new records
# 🔍 2018 - Z_J
# 📦 Page 1: 7 new records
# 🔍 2018 - Z_K
# 📦 Page 1: 29 new records
# 🔍 2018 - Z_L
# 📦 Page 1: 31 new records
# 🔍 2018 - Z_M
# 📦 Page 1: 31 new records
# 🔍 2018 - Z_N
# 📦 Page 1: 1 new records
# 🔍 2018 - Z_O
# 📦 Page 1: 1 new records
# 🔍 2018 - Z_P
# 📦 Page 1: 16 new records
# 🔍 2018 - Z_Q
# 📦 Page 1: 3 new records
# 🔍 2018 - Z_R
# 📦 Page 1: 8 new records
# 🔍 2018 - Z_S
# 📦 Page 1: 37 new records
# 🔍 2018 - Z_T
# 📦 Page 1: 9 new records
# 🔍 2018 - Z_U
# 🔍 2018 - Z_V
# 📦 Page 1: 2 new records
# 🔍 2018 - Z_W
# 📦 Page 1: 17 new records
# 🔍 2018 - Z_X
# 🛑 Page 1: No new records
# 🔍 2018 - Z_Y
# 📦 Page 1: 6 new records
# 🔍 2018 - Z_Z
# 📦 Page 1: 29 new records
# 💾 Saved full CSV for 2018 with 36501 records
#
# ✅ All years completed.

# %%
for year in range(2017, 2018):
    print(year)
# Out:
# 2017

# %%
import pandas as pd
import json
from pathlib import Path

# Folder containing all the pair files
jsonl_dir = Path("raw/hsc_achievers")
output_csv_path = Path("raw/hsc_achievers_combined.csv")

# Load all jsonl files
records = []
for file in jsonl_dir.glob("*.jsonl"):
    with open(file, "r") as f:
        for line in f:
            try:
                record = json.loads(line.strip())
                source = record.get("_source", {})
                records.append(source)
            except json.JSONDecodeError:
                print(f"❌ Could not parse line in {file}")
                continue

# Convert to DataFrame and save as CSV
df = pd.DataFrame(records)
df.to_csv(output_csv_path, index=False)
print(f"✅ Combined {len(df)} records into {output_csv_path}")
# Out:
# ✅ Combined 41945 records into raw/hsc_achievers_combined.csv
